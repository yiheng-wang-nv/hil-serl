# %%
from serl_robot_infra.unitree_env import UnitreeG1ArmEnv
import numpy as np

env = UnitreeG1ArmEnv(server_url="http://127.0.0.1:6000/")
obs, info = env.reset()
action = np.zeros(14, dtype=np.float32)
obs, reward, terminated, truncated, info = env.step(action)
env.close()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[1], line 7
#       5 obs, info = env.reset()
#       6 action = np.zeros(14, dtype=np.float32)
# ----> 7 obs, reward, terminated, truncated, info = env.step(action)
#       8 env.close()
#
# File ~/code/hil-serl/serl_robot_infra/unitree_env/unitree_arm_env.py:91, in UnitreeG1ArmEnv.step(self, action)
#      89 def step(self, action: np.ndarray):
#      90     clipped = np.clip(action, self.action_space.low, self.action_space.high)
# ---> 91     self._send_joint_targets(clipped)
#      92     state = self._fetch_state()
#      93     obs = self._compose_obs(state)
#
# File ~/code/hil-serl/serl_robot_infra/unitree_env/unitree_arm_env.py:70, in UnitreeG1ArmEnv._send_joint_targets(self, targets)
#      68 payload = {"joint_positions": targets.astype(float).tolist()}
#      69 response = requests.post(self.server_url + "joint_position", json=payload, timeout=1.0)
# ---> 70 response.raise_for_status()
#
# File ~/miniconda3/envs/hilserl/lib/python3.10/site-packages/requests/models.py:1026, in Response.raise_for_status(self)
#    1021     http_error_msg = (
#    1022         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1023     )
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 500 Server Error: INTERNAL SERVER ERROR for url: http://127.0.0.1:6000/joint_position
